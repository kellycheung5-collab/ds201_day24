# %%
import pandas as pd
import numpy as np

# Generate sample sales data
np.random.seed(42)
df = pd.DataFrame({
    'date': pd.date_range('2024-01-01', periods=50),
    'region': np.random.choice(['North', 'South', 'East', 'West'], 50),
    'revenue': np.random.randint(1000, 9999, 50),
    'units': np.random.randint(10, 200, 50)
})
print(f'Dataset shape: {df.shape}')
df.head(10)
# Out:
# Dataset shape: (50, 4)
#         date region  revenue  units
# 0 2024-01-01   East     3734     24
# 1 2024-01-02   West     4005     54
# 2 2024-01-03  North     5658     74
# 3 2024-01-04   East     2899     98
# 4 2024-01-05   East     8734     80
# 5 2024-01-06   West     2267     18
# 6 2024-01-07  North     2528     97
# 7 2024-01-08  North     4556    138
# 8 2024-01-09   East     4890    145
# 9 2024-01-10  South     9838     72

# %%
# Summary statistics by region
summary = df.groupby('region').agg(
    total_revenue=('revenue', 'sum'),
    avg_units=('units', 'mean'),
    count=('revenue', 'count')
).round(2)
print('Revenue summary by region:')
print(summary)
# Out:
# Revenue summary by region:
#         total_revenue  avg_units  count
# region
# East            92155     100.38     13
# North           51118     103.10     10
# South           59572      91.73     11
# West           104878      83.25     16

# %%
# Execution count test — this cell exists so the execution count is clearly non-zero
# Run this cell exactly twice before committing
print(f'Execution count will be visible in git diff')
print(f'Total revenue: ${df["revenue"].sum():,}')
# Out:
# Execution count will be visible in git diff
# Total revenue: $307,723
